# %% [markdown]
# # Integrating breast cancer datasets using EmbedMNN model
#
# In this example, we will use *transmorph* to integrate lung datasets from three patients, gathered in [1]. These datasets contain a total of approximately 100,000 cells, annotated by cell type. Each dataset is embedded in its own 10,000 most variable gene space, and we exploit the intersection of these gene spaces to carry out dataset integration.
#
# We use one of our built-in models, **EmbedMNN**, to carry out the integration. It combines a few preprocessing steps (common genes space embedding, normalization and dimensionality reduction) with a mutual nearest neighbors (MNN)-based matching [2, 3] and a low-dimensional space embedding using UMAP [4] or MDE [5]. This low dimensional space can subsequently be used to carry out tasks such as clustering.

# %% [markdown]
# ### Loading the data bank
#
# *transmorph* provides a few data banks for testing purposes, already preprocessed (cell/gene filtering, normalization, log1p...) and annotated. They can be loaded using *datasets* module. Breast cancer databank contains five datasets in the AnnData format, each expressed in its 10,000 most variable genes space. Cells are annotated by the .obs key "class_type". If the queried databank is missing, it will be automatically downloaded, and saved locally for faster subsequent access.

# %%
from transmorph.datasets import load_chen_10x

# Format: {patient_label -> AnnData}
chen_10x = load_chen_10x()

chen_10x_new = {}
for key, adata in chen_10x.items(): # Getting rid of artifacts
    adata = adata[adata.obs['class'] != 'n/a', :]
    adata = adata[adata.obs['class'] != 'Mast', :]
    adata = adata[adata.obs['class'] != 'Myofibroblast', :]
    adata = adata[adata.obs['class'] != 'Lymphovascular', :]
    adata = adata[adata.obs['class'] != 'Fibroblast', :]
    adata = adata[adata.obs['class'] != 'Dendritic', :]
    
    chen_10x_new[key] = adata
chen_10x = chen_10x_new
    
# We convert it to List[AnnData] as we do not 
# care about label here
datasets = list(chen_10x.values())
# Out:
# databank_api > Loading bank chen_10x.
# databank_api > Bank chen_10x successfully loaded.

# %% [markdown]
# We can first observe the cell type distribution in each dataset. As we can see, batch 3 contains an exclusive cell type (endothelial cells), and batch 4 contains almost exclusively epithelial cells and fibroblast. This suggests the integration to be nontrivial, as there is a high cell type imbalance between batches.

# %%
from transmorph.utils.plotting import plot_label_distribution_heatmap

plot_label_distribution_heatmap(datasets, "class", dataset_keys=chen_10x.keys())

# %% [markdown]
# ### Plotting initial datasets using scatter_plot
#
# *transmorph.plotting.reduce_dimension* can be used to compute a low dimensional representation of a set of datasets, and save the output in the respective AnnData objects under an access key. Batches can then be represented using *transmmorph.plotting.scatter_plot*.

# %%
from transmorph.utils.plotting import scatter_plot, reduce_dimension

reduce_dimension(datasets, output_obsm="before_transmorph")

# use_cache=True allows to avoid recomputing a UMAP representation for each plot
scatter_plot(
    datasets, 
    input_obsm="before_transmorph",
)
scatter_plot(
    datasets, 
    color_by="class",
    input_obsm="before_transmorph"
)

# %% [markdown]
# As we can see, batch effect is very strong even in the common gene space. In this state, it is impossible to attempt a clustering algorithm for instance, as cells are clustered per batch as clearly as per cell type. *transmorph* is equiped with pre-built integration models to integrate these batches so that similar cell types cluster together.
#
# ### Dataset integration using EmbedMNN
#
# **EmbedMNN** combines an inter-batch nearest neighbors step followed with a low-dimensional embedding, here using UMAP. Parameters can be tuned during model instanciation. Model can then be ran using transform() method, providing a list of AnnData objects. It will add a .obsm["transmorph"] entry, corresponding to the integrated view computed. While the nearest neighbors step should easily handle datasets of this size, the UMAP optimizer can take some time when dealing with 100,000 cells, connected with millions of edges. It should nonetheless remain reasonable, even on a laptop.
#
# **This model starts by embedding all datasets in a common genes space, therefore there must exists a nonempty intersection between all .var_names.**

# %%
from transmorph.models import EmbedMNN

# Using these two parameters, we can tune the balance
# between matching edges and knn edges.
model = EmbedMNN() 
model.transform(datasets)
# Out:
# EMBED_MNN > Transmorph model is initializing.
# EMBED_MNN > Ready to start the integration of 14 datasets, 61870 total samples.
# EMBED_MNN > Running layer LAYER_INPUT#0.
# EMBED_MNN > Running layer LAYER_TRANSFORMATION#1.
# EMBED_MNN > Running layer LAYER_MATCHING#2.
# LAYER_MATCHING#2 > Calling matching MATCHING_MNN.
# EMBED_MNN > Running layer LAYER_MERGING#3.
# LAYER_MERGING#3 > Running merging MERGING_GRAPH_EMBEDDING...
# EMBED_MNN > Running layer LAYER_OUTPUT#4.
# EMBED_MNN > Terminated. Total embedding shape: (61870, 2)
# EMBED_MNN > Results have been written in AnnData.obsm['transmorph'].
# EMBED_MNN > Transmorph model is initializing.
# EMBED_MNN > Ready to start the integration of 14 datasets, 61870 total samples.
# EMBED_MNN > Running layer LAYER_INPUT#0.
# EMBED_MNN > Running layer LAYER_TRANSFORMATION#1.
# EMBED_MNN > Running layer LAYER_MATCHING#2.
# LAYER_MATCHING#2 > Calling matching MATCHING_MNN.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 7>()
#       5 model = EmbedMNN()
#       6 model.transform(datasets)
# ----> 7 model.transform(datasets)
#
# File ~/Documents/PHD/coding/transmorph_local/transmorph/src/transmorph/models/embedmnn.py:176, in EmbedMNN.transform(self, datasets, use_representation)
#     159 def transform(
#     160     self,
#     161     datasets: List[AnnData],
#     162     use_representation: Optional[str] = None,
#     163 ) -> None:
#     164     """
#     165     Carries out the model on a list of AnnData objects. Writes the result in
#     166     .obsm fields.
#    (...)
#     174         .obsm to use as input.
#     175     """
# --> 176     self.fit(
#     177         datasets=datasets,
#     178         reference=None,
#     179         use_representation=use_representation,
#     180     )
#
# File ~/Documents/PHD/coding/transmorph_local/transmorph/src/transmorph/engine/model.py:193, in Model.fit(self, datasets, reference, use_representation)
#     191 called = layers_to_run.pop(0)
#     192 self.info(f"Running layer {called}.")
# --> 193 output_layers = called.fit(datasets)
#     195 # Invalid checking -> layer rejected
#     196 if isinstance(called, LayerChecking) and called.check_is_valid:
#
# File ~/Documents/PHD/coding/transmorph_local/transmorph/src/transmorph/engine/traits/isprofilable.py:21, in profile_method.<locals>.wrapper(*args)
#      19 tstr = f"{str(self)}.{method.__name__}"
#      20 tid = profiler.task_start(tstr)
# ---> 21 result = method(*args)
#      22 elapsed = profiler.task_end(tid)
#      23 self.time_elapsed[tstr] = elapsed
#
# File ~/Documents/PHD/coding/transmorph_local/transmorph/src/transmorph/engine/layers/layermatching.py:134, in LayerMatching.fit(self, datasets)
#     132 self.info(f"Calling matching {self.matching}.")
#     133 self.matching_matrices = {}
# --> 134 for key, T in self.matching.fit(Xs).items():
#     135     i, j = key
#     136     T = self.unsubsample_matrix(T, i, j)
#
# File ~/Documents/PHD/coding/transmorph_local/transmorph/src/transmorph/engine/traits/isprofilable.py:21, in profile_method.<locals>.wrapper(*args)
#      19 tstr = f"{str(self)}.{method.__name__}"
#      20 tid = profiler.task_start(tstr)
# ---> 21 result = method(*args)
#      22 elapsed = profiler.task_end(tid)
#      23 self.time_elapsed[tstr] = elapsed
#
# File ~/Documents/PHD/coding/transmorph_local/transmorph/src/transmorph/engine/matching/algorithms/bknn.py:93, in BKNN.fit(self, datasets)
#      91 qtrees = []
#      92 if self.solver == "nndescent":
# ---> 93     qtrees = [
#      94         generate_qtree(X, self.metric, self.metric_kwargs) for X in datasets
#      95     ]
#      96 ndatasets = len(datasets)
#      97 results: _TypeMatchingSet = {}
#
# File ~/Documents/PHD/coding/transmorph_local/transmorph/src/transmorph/engine/matching/algorithms/bknn.py:94, in <listcomp>(.0)
#      91 qtrees = []
#      92 if self.solver == "nndescent":
#      93     qtrees = [
# ---> 94         generate_qtree(X, self.metric, self.metric_kwargs) for X in datasets
#      95     ]
#      96 ndatasets = len(datasets)
#      97 results: _TypeMatchingSet = {}
#
# File ~/Documents/PHD/coding/transmorph_local/transmorph/src/transmorph/utils/graph.py:180, in generate_qtree(X, metric, metric_kwargs)
#     178     metric_kwargs = {}
#     179 qtree = NNDescent(X, metric=metric, metric_kwds=metric_kwargs)
# --> 180 qtree.prepare()
#     181 return qtree
#
# File ~/.local/share/virtualenvs/transmorph_local-RhkhmxdW/lib/python3.9/site-packages/pynndescent/pynndescent_.py:1592, in NNDescent.prepare(self)
#    1590         self._init_sparse_search_function()
#    1591     else:
# -> 1592         self._init_search_function()
#    1593 return
#
# File ~/.local/share/virtualenvs/transmorph_local-RhkhmxdW/lib/python3.9/site-packages/pynndescent/pynndescent_.py:1325, in NNDescent._init_search_function(self)
#    1323 # Force compilation of the search function (hardcoded k, epsilon)
#    1324 query_data = self._raw_data[:1]
# -> 1325 inds, dists, _ = self._search_function(
#    1326     query_data, 5, 0.0, self._visited, self.search_rng_state
#    1327 )
#    1328 _ = self._deheap_function(inds, dists)
#
# File ~/.local/share/virtualenvs/transmorph_local-RhkhmxdW/lib/python3.9/site-packages/numba/core/dispatcher.py:420, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     418 return_val = None
#     419 try:
# --> 420     return_val = self.compile(tuple(argtypes))
#     421 except errors.ForceLiteralArg as e:
#     422     # Received request for compiler re-entry with the list of arguments
#     423     # indicated by e.requested_args.
#     424     # First, check if any of these args are already Literal-ized
#     425     already_lit_pos = [i for i in e.requested_args
#     426                        if isinstance(args[i], types.Literal)]
#
# File ~/.local/share/virtualenvs/transmorph_local-RhkhmxdW/lib/python3.9/site-packages/numba/core/dispatcher.py:965, in Dispatcher.compile(self, sig)
#     963 with ev.trigger_event("numba:compile", data=ev_details):
#     964     try:
# --> 965         cres = self._compiler.compile(args, return_type)
#     966     except errors.ForceLiteralArg as e:
#     967         def folded(args, kws):
#
# File ~/.local/share/virtualenvs/transmorph_local-RhkhmxdW/lib/python3.9/site-packages/numba/core/dispatcher.py:125, in _FunctionCompiler.compile(self, args, return_type)
#     124 def compile(self, args, return_type):
# --> 125     status, retval = self._compile_cached(args, return_type)
#     126     if status:
#     127         return retval
#
# File ~/.local/share/virtualenvs/transmorph_local-RhkhmxdW/lib/python3.9/site-packages/numba/core/dispatcher.py:139, in _FunctionCompiler._compile_cached(self, args, return_type)
#     136     pass
#     138 try:
# --> 139     retval = self._compile_core(args, return_type)
#     140 except errors.TypingError as e:
#     141     self._failed_cache[key] = e
#
# File ~/.local/share/virtualenvs/transmorph_local-RhkhmxdW/lib/python3.9/site-packages/numba/core/dispatcher.py:152, in _FunctionCompiler._compile_core(self, args, return_type)
#     149 flags = self._customize_flags(flags)
#     151 impl = self._get_implementation(args, {})
# --> 152 cres = compiler.compile_extra(self.targetdescr.typing_context,
#     153                               self.targetdescr.target_context,
#     154                               impl,
#     155                               args=args, return_type=return_type,
#     156                               flags=flags, locals=self.locals,
#     157                               pipeline_class=self.pipeline_class)
#     158 # Check typing error if object mode is used
#     159 if cres.typing_error is not None and not flags.enable_pyobject:
#
# File ~/.local/share/virtualenvs/transmorph_local-RhkhmxdW/lib/python3.9/site-packages/numba/core/compiler.py:693, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     669 """Compiler entry point
#     670
#     671 Parameter
#    (...)
#     689     compiler pipeline
#     690 """
#     691 pipeline = pipeline_class(typingctx, targetctx, library,
#     692                           args, return_type, flags, locals)
# --> 693 return pipeline.compile_extra(func)
#
# File ~/.local/share/virtualenvs/transmorph_local-RhkhmxdW/lib/python3.9/site-packages/numba/core/compiler.py:429, in CompilerBase.compile_extra(self, func)
#     427 self.state.lifted = ()
#     428 self.state.lifted_from = None
# --> 429 return self._compile_bytecode()
#
# File ~/.local/share/virtualenvs/transmorph_local-RhkhmxdW/lib/python3.9/site-packages/numba/core/compiler.py:497, in CompilerBase._compile_bytecode(self)
#     493 """
#     494 Populate and run pipeline for bytecode input
#     495 """
#     496 assert self.state.func_ir is None
# --> 497 return self._compile_core()
#
# File ~/.local/share/virtualenvs/transmorph_local-RhkhmxdW/lib/python3.9/site-packages/numba/core/compiler.py:463, in CompilerBase._compile_core(self)
#     461 res = None
#     462 try:
# --> 463     pm.run(self.state)
#     464     if self.state.cr is not None:
#     465         break
#
# File ~/.local/share/virtualenvs/transmorph_local-RhkhmxdW/lib/python3.9/site-packages/numba/core/compiler_machinery.py:341, in PassManager.run(self, state)
#     339 pass_inst = _pass_registry.get(pss).pass_inst
#     340 if isinstance(pass_inst, CompilerPass):
# --> 341     self._runPass(idx, pass_inst, state)
#     342 else:
#     343     raise BaseException("Legacy pass in use")
#
# File ~/.local/share/virtualenvs/transmorph_local-RhkhmxdW/lib/python3.9/site-packages/numba/core/compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File ~/.local/share/virtualenvs/transmorph_local-RhkhmxdW/lib/python3.9/site-packages/numba/core/compiler_machinery.py:296, in PassManager._runPass(self, index, pss, internal_state)
#     294     mutated |= check(pss.run_initialization, internal_state)
#     295 with SimpleTimer() as pass_time:
# --> 296     mutated |= check(pss.run_pass, internal_state)
#     297 with SimpleTimer() as finalize_time:
#     298     mutated |= check(pss.run_finalizer, internal_state)
#
# File ~/.local/share/virtualenvs/transmorph_local-RhkhmxdW/lib/python3.9/site-packages/numba/core/compiler_machinery.py:269, in PassManager._runPass.<locals>.check(func, compiler_state)
#     268 def check(func, compiler_state):
# --> 269     mangled = func(compiler_state)
#     270     if mangled not in (True, False):
#     271         msg = ("CompilerPass implementations should return True/False. "
#     272                "CompilerPass with name '%s' did not.")
#
# File ~/.local/share/virtualenvs/transmorph_local-RhkhmxdW/lib/python3.9/site-packages/numba/core/typed_passes.py:394, in NativeLowering.run_pass(self, state)
#     391 with targetctx.push_code_library(library):
#     392     lower = lowering.Lower(targetctx, library, fndesc, interp,
#     393                            metadata=metadata)
# --> 394     lower.lower()
#     395     if not flags.no_cpython_wrapper:
#     396         lower.create_cpython_wrapper(flags.release_gil)
#
# File ~/.local/share/virtualenvs/transmorph_local-RhkhmxdW/lib/python3.9/site-packages/numba/core/lowering.py:196, in BaseLower.lower(self)
#     194 if self.generator_info is None:
#     195     self.genlower = None
# --> 196     self.lower_normal_function(self.fndesc)
#     197 else:
#     198     self.genlower = self.GeneratorLower(self)
#
# File ~/.local/share/virtualenvs/transmorph_local-RhkhmxdW/lib/python3.9/site-packages/numba/core/lowering.py:250, in BaseLower.lower_normal_function(self, fndesc)
#     248 # Init argument values
#     249 self.extract_function_arguments()
# --> 250 entry_block_tail = self.lower_function_body()
#     252 # Close tail of entry block, do not emit debug metadata else the
#     253 # unconditional jump gets associated with the metadata from the function
#     254 # body end.
#     255 with debuginfo.suspend_emission(self.builder):
#
# File ~/.local/share/virtualenvs/transmorph_local-RhkhmxdW/lib/python3.9/site-packages/numba/core/lowering.py:279, in BaseLower.lower_function_body(self)
#     277     bb = self.blkmap[offset]
#     278     self.builder.position_at_end(bb)
# --> 279     self.lower_block(block)
#     280 self.post_lower()
#     281 return entry_block_tail
#
# File ~/.local/share/virtualenvs/transmorph_local-RhkhmxdW/lib/python3.9/site-packages/numba/core/lowering.py:293, in BaseLower.lower_block(self, block)
#     290     defaulterrcls = partial(LoweringError, loc=self.loc)
#     291     with new_error_context('lowering "{inst}" at {loc}', inst=inst,
#     292                            loc=self.loc, errcls_=defaulterrcls):
# --> 293         self.lower_inst(inst)
#     294 self.post_block(block)
#
# File ~/.local/share/virtualenvs/transmorph_local-RhkhmxdW/lib/python3.9/site-packages/numba/core/lowering.py:438, in Lower.lower_inst(self, inst)
#     436 if isinstance(inst, ir.Assign):
#     437     ty = self.typeof(inst.target.name)
# --> 438     val = self.lower_assign(ty, inst)
#     439     argidx = None
#     440     # If this is a store from an arg, like x = arg.x then tell debuginfo
#     441     # that this is the arg
#
# File ~/.local/share/virtualenvs/transmorph_local-RhkhmxdW/lib/python3.9/site-packages/numba/core/lowering.py:630, in Lower.lower_assign(self, ty, inst)
#     628     oty = self.typeof(value.name)
#     629     res = self.context.cast(self.builder, val, oty, ty)
# --> 630     self.incref(ty, res)
#     631     return res
#     633 elif isinstance(value, ir.Arg):
#     634     # Suspend debug info else all the arg repacking ends up being
#     635     # associated with some line or other and it's actually just a detail
#     636     # of Numba's CC.
#
# File ~/.local/share/virtualenvs/transmorph_local-RhkhmxdW/lib/python3.9/site-packages/numba/core/lowering.py:1513, in Lower.incref(self, typ, val)
#    1510 if not self.context.enable_nrt:
#    1511     return
# -> 1513 self.context.nrt.incref(self.builder, typ, val)
#
# KeyboardInterrupt:

# %% [markdown]
# # Post-integration analysis
#
# Transmorph offers a series of tools to process and interpret integration output.
#
# We can first use *scatter_plot* once again, providing the access key "transmorph" as the output dimensionality is already 2D. As we can see, **EmbedMNN** successfully captures cell types across batches, and provides a coherent integrated representation of batches.

# %%
from transmorph.utils.plotting import scatter_plot

scatter_plot(datasets, input_obsm="transmorph", xlabel="TR1", ylabel="TR2", title="transmorph")
scatter_plot(
    datasets, color_by="class", show_legend=False, plot_cluster_names=True, 
    input_obsm="transmorph", xlabel="TR1", ylabel="TR2", title="transmorph"
)

# %% [markdown]
# An important pipeline step of EmbedMNN is the matching across batches, carried out via MNN or bach k-NN. The *plot_matching_eval* method allows to see, for each pair of datasets, and given a label ground truth, how accurate edges. Accuracy 1.0 means all edges connect samples of the same class, and 0.0 means complete matching failure for the given labels. As we can see, in our case cell type matching was near perfect.

# %%
from transmorph.utils.plotting import plot_matching_eval

plot_matching_eval(model, datasets, obs="class", dataset_keys=chen_10x.keys())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [6], in <cell line: 3>()
#       1 from transmorph.utils.plotting import plot_matching_eval
# ----> 3 plot_matching_eval(model, datasets, obs="class", dataset_keys=chen_10x.keys())
#
# File ~/Documents/PHD/coding/transmorph_local/transmorph/src/transmorph/utils/plotting.py:465, in plot_matching_eval(model, datasets, obs, dataset_keys, title, matshow_kwargs)
#     463 else:
#     464     evaluator = matching_edge_penalty_continuous(obs)
# --> 465 scores = evaluate_matching_layer(layer_matching, datasets, evaluator)
#     466 ndatasets = scores.shape[0]
#     467 if dataset_keys is not None:
#
# File ~/Documents/PHD/coding/transmorph_local/transmorph/src/transmorph/engine/evaluators/matching_evaluators.py:35, in evaluate_matching_layer(layer, datasets, evaluator)
#      32 for i in range(ndatasets):
#      33     for j in range(i + 1, ndatasets):
#      34         results[i, j] = results[j, i] = evaluator(
# ---> 35             datasets[i], datasets[j], matchings[i, j]
#      36         )
#      37 return results
#
# KeyError: (0, 1)

# %% [markdown]
# ## References
#
# [1] Pal, B. et al. *A single‐cell RNA expression atlas of normal, preneoplastic and tumorigenic states in the human breast*. **The EMBO journal** (2021), 40(11), e107333.
#
# [2] Haghverdi, Laleh, et al. *Batch effects in single-cell RNA-sequencing data are corrected by matching mutual nearest neighbors.* **Nature biotechnology** 36.5 (2018): 421-427.
#
# [3]  Polański, Krzysztof, et al. *BBKNN: fast batch alignment of single cell transcriptomes.* **Bioinformatics** 36.3 (2020): 964-965.
#
# [4] Becht, Etienne, et al. *Dimensionality reduction for visualizing single-cell data using UMAP.* **Nature biotechnology** 37.1 (2019): 38-44.
#
# [5] Agrawal, Akshay, Alnur Ali, and Stephen Boyd. *Minimum-distortion embedding.* **arXiv preprint** arXiv:2103.02559 (2021).
