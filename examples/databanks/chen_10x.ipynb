# %%
from transmorph.datasets import load_chen_10x

datasets = load_chen_10x()
# Out:
# databank_api > Loading bank chen_10x.
# databank_api > Bank chen_10x successfully loaded.

# %%
sum([dataset.n_obs for dataset in datasets.values()])
# Out:
# 61870

# %%
from transmorph.utils.plotting import plot_label_distribution_heatmap

plot_label_distribution_heatmap(datasets, label='class')

# %%
min([dataset.n_obs for dataset in datasets.values()])
# Out:
# 1087

# %%
max([dataset.n_obs for dataset in datasets.values()])
# Out:
# 11210

# %%
'*, *'.join(sorted(set(datasets['P01'].obs['class'])))
# Out:
# 'B cell*, *Endothelial*, *Epithelial*, *Macrophage*, *Malignant*, *NK_cell*, *Plasma*, *T cell'
