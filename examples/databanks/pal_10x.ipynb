# %%
from transmorph.datasets import load_pal_10x

datasets = load_pal_10x()
# Out:
# databank_api > Loading bank pal_10x.
# databank_api > Bank pal_10x successfully loaded.

# %%
sum([dataset.n_obs for dataset in datasets.values()])
# Out:
# 93167

# %%
from transmorph.utils.plotting import plot_label_distribution_heatmap

plot_label_distribution_heatmap(datasets, label='class_type')

# %%
min([dataset.n_obs for dataset in datasets.values()])
# Out:
# 3782

# %%
max([dataset.n_obs for dataset in datasets.values()])
# Out:
# 36774

# %%
'*, *'.join(sorted(set(datasets['P01'].obs['class'])))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 '*, *'.join(sorted(set(datasets['P01'].obs['class'])))
#
# KeyError: 'P01'
