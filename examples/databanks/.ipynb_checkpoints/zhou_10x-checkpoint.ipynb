# %%
from transmorph.datasets import load_zhou_10x

datasets = load_zhou_10x()
# Out:
# databank_api > Loading bank zhou_10x.
# databank_api > Loading dataset zhou_10x...
# databank_api > Reference: https://www.nature.com/articles/s41467-020-20059-6
# databank_api > Type: single-cell RNA-seq 10X
# databank_api > Number of files: 11
# databank_api > Dataset zhou_10x successfully downloaded.
# databank_api > Bank zhou_10x successfully loaded.

# %%
sum([dataset.n_obs for dataset in datasets.values()])
# Out:
# 64557

# %%
from transmorph.utils.plotting import plot_label_distribution_heatmap

plot_label_distribution_heatmap(datasets, label='class_type')

# %%
min([dataset.n_obs for dataset in datasets.values()])
# Out:
# 866

# %%
max([dataset.n_obs for dataset in datasets.values()])
# Out:
# 14322
